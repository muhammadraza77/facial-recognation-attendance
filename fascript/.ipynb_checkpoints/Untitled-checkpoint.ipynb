# %%
import cv2
import os,sys
import matplotlib.pyplot as plt

vidcap = cv2.VideoCapture(0)
# success,image = vidcap.read(0)
count = 0
cwd = os.getcwd()
user_name = 'raza vasnani'
dir = cwd + '/train_img/' + user_name
if not os.path.exists(dir):
    os.makedirs(dir)
success = True

while True and count!=100:
    
    success,image = vidcap.read(0)
#     cv2.imshow('img',image)
    
    print(cv2.imwrite("train_img/"+user_name+"/frame%d.jpg" % count, image))     # save frame as JPEG file
    print('Read a new frame: ', success)
    count += 1
  
vidcap.release()
cv2.destroyAllWindows()
# Out:
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True

# %%
import cv2
import os,sys
import matplotlib.pyplot as plt

cap = cv2.VideoCapture(0) 
count = 0
cwd = os.getcwd()
user_name = 'pakistan'
dir = cwd + '/train_img/' + user_name
if not os.path.exists(dir):
    os.makedirs(dir)

while True: 
    
    ret, input_image_77 = cap.read(0) 

    cv2.imshow('Video Face Detection', input_image_77) 
    
    
    print(cv2.imwrite("train_img/"+user_name+"/frame%d.jpg" % count, image))     # save frame as JPEG file
    print('Read a new frame: ', success)
    count += 1
 
    c = cv2.waitKey(1) 
    if c == 27:
        print(cv2.imwrite('download.jpg', input_image_77))     # save frame as JPEG file
        break 
        
cap.release() 
cv2.destroyAllWindows()
# Out:
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
# Read a new frame:  True
# True
